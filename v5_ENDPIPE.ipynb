# %% [markdown]
# <a href="https://colab.research.google.com/github/susara20010420/Workplace-Safety-Insights-from-the-Industrial-Safety-Health-Analytics-Dataset/blob/main/v5_ENDPIPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJECT_FOLDER = "/content/drive/MyDrive/Work Place Safety Insights"

SCRIPT = (
    "/content/drive/MyDrive/Work Place Safety Insights/"
    "dashboard_scripts/build_dashboard_snapshot.py"
)

OUTPUT = (
    "/content/drive/MyDrive/Work Place Safety Insights/"
    "dashboard_snapshot.json"
)

# %%
# !python "$SCRIPT" \
    --project-folder "$PROJECT_FOLDER" \
    --output "$OUTPUT"
# Out:
# python3: can't open file '/content/drive/MyDrive/Work Place Safety Insights/dashboard_scripts/build_dashboard_snapshot.py': [Errno 2] No such file or directory
